# %% [markdown]
# # Activity 6: Creating an active training environment
# In this activity we learn to evaluate our LSTM model and to actively train it with new data.

# %% [markdown]
# ## Load Data

# %%
"""Utility functions used in Activity 6."""

import numpy as np


def create_groups(data, group_size=7):
    """Create distinct groups from a continuous series.

    Parameters
    ----------
    data: np.array
        Series of continious observations.

    group_size: int, default 7
        Determines how large the groups are. That is,
        how many observations each group contains.

    Returns
    -------
    A Numpy array object.
    """
    samples = list()
    for i in range(0, len(data), group_size):
        sample = list(data[i:i + group_size])
        if len(sample) == group_size:
            samples.append(np.array(sample).reshape(1, group_size).tolist())

    a = np.array(samples)
    return a.reshape(1, a.shape[0], group_size)


def split_lstm_input(groups):
    """Split groups in a format expected by the LSTM layer.

    Parameters
    ----------
    groups: np.array
        Numpy array with the organized sequences.

    Returns
    -------
    X, Y: np.array
        Numpy arrays with the shapes required by
        the LSTM layer. X with (1, a - 1, b)
        and Y with (1, b). Where a is the total
        number of groups in `group` and b the
        number of observations per group.
    """
    X = groups[0:, :-1].reshape(1, groups.shape[1] - 1, groups.shape[2])
    Y = groups[0:, -1:][0]

    return X, Y


def mape(A, B):
    """Calculate the mean absolute percentage error from two series."""
    return np.mean(np.abs((A - B) / A)) * 100


def rmse(A, B):
    """Calculate the root mean square error from two series."""
    return np.sqrt(np.square(np.subtract(A, B)).mean())

# %%
# %autosave 5

#  Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-white')

from keras.models import load_model
from keras.callbacks import TensorBoard
from datetime import datetime, timedelta

#from scripts.utilities_activity6 import *

np.random.seed(0)
# Out:
# Autosaving every 5 seconds

# %%
#  Load datasets
train = pd.read_csv('train_dataset1.csv')
test = pd.read_csv('test_dataset.csv')

# %%
#  Group data into groups containing seven observations
train_data = create_groups(
    train['close_point_relative_normalization'][2:].values)

test_data = create_groups(
    test['close_point_relative_normalization'][:-3].values)

# %%
#  Reshape the data in the format expected by the LSTM layer
X_train, Y_train = split_lstm_input(train_data)

# %% [markdown]
# ## Re-train Model with TensorBoard

# %%
def train_model(model, X, Y, epochs, version, run_number):
    """Training a model with TensorBoard callback.

    This function names each run of the model
    using the TensorBoard naming conventions.

    Parameters
    ----------
    model: Keras model instance
        Compiled Keras model.

    X, Y: np.array
        Series of observations to be used in
        the training process.

    epochs: int
        The number of epochs to train the
        model for.

    version: int
        Version of the model to run.

    run_number: int
        The number of the run. Used in case
        the same model version is run again.
    """
    model_name = f'bitcoin_lstm_v{version}_run_{run_number}'
    tensorboard = TensorBoard(log_dir=f'./logs/{model_name}')

    #  TASK:
    #  Modify the `fit` method to include a TensorBoard callback.
    #
    model_history = model.fit(
        x=X, y=Y,
        batch_size=1, epochs=epochs,
        shuffle=False, callbacks=[tensorboard]
        )

    return model_history

# %%
#  Load previously trained network
model = load_model('bitcoin_lstm_v0.h5')

# %%
#  Retrain network
model_history = train_model(model=model,
                            X=X_train, Y=Y_train,
                            epochs=1000,
                            version=0, run_number=2)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0031
# Epoch 2/1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 3/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 4/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 7/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 8/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 9/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.8085e-04
# Epoch 10/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.7883e-04
# Epoch 11/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.8717e-04
# Epoch 12/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.0435e-04
# Epoch 13/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.2922e-04
# Epoch 14/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.6089e-04
# Epoch 15/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9866e-04
# Epoch 16/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.4198e-04
# Epoch 17/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9036e-04
# Epoch 18/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4344e-04
# Epoch 19/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0086e-04
# Epoch 20/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6233e-04
# Epoch 21/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2757e-04
# Epoch 22/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9635e-04
# Epoch 23/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6842e-04
# Epoch 24/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4355e-04
# Epoch 25/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2155e-04
# Epoch 26/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0219e-04
# Epoch 27/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.5267e-05
# Epoch 28/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.0586e-05
# Epoch 29/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.7944e-05
# Epoch 30/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7148e-05
# Epoch 31/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8008e-05
# Epoch 32/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0341e-05
# Epoch 33/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3971e-05
# Epoch 34/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8734e-05
# Epoch 35/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4473e-05
# Epoch 36/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1047e-05
# Epoch 37/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3238e-06
# Epoch 38/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1872e-06
# Epoch 39/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5330e-06
# Epoch 40/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2704e-06
# Epoch 41/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3211e-06
# Epoch 42/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6188e-06
# Epoch 43/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1080e-06
# Epoch 44/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4328e-07
# Epoch 45/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8793e-07
# Epoch 46/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1292e-07
# Epoch 47/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9570e-07
# Epoch 48/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1914e-07
# Epoch 49/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0794e-08
# Epoch 50/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5055e-08
# Epoch 51/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 8.0039e-08
# Epoch 52/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6667e-07
# Epoch 53/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2562e-06
# Epoch 54/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9554e-06
# Epoch 55/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8102e-06
# Epoch 56/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3224e-06
# Epoch 57/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1271e-06
# Epoch 58/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4877e-06
# Epoch 59/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8987e-06
# Epoch 60/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5555e-06
# Epoch 61/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4882e-06
# Epoch 62/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6992e-06
# Epoch 63/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9250e-06
# Epoch 64/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0093e-06
# Epoch 65/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9141e-06
# Epoch 66/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8873e-06
# Epoch 67/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9284e-06
# Epoch 68/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1612e-06
# Epoch 69/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5089e-06
# Epoch 70/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9206e-06
# Epoch 71/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1460e-06
# Epoch 72/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0960e-06
# Epoch 73/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8247e-06
# Epoch 74/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5685e-06
# Epoch 75/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3964e-06
# Epoch 76/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4238e-06
# Epoch 77/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5098e-06
# Epoch 78/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6993e-06
# Epoch 79/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7338e-06
# Epoch 80/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7900e-06
# Epoch 81/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6529e-06
# Epoch 82/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6034e-06
# Epoch 83/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4341e-06
# Epoch 84/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4006e-06
# Epoch 85/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3479e-06
# Epoch 86/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5516e-06
# Epoch 87/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.0523e-06
# Epoch 88/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8316e-06
# Epoch 89/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8965e-06
# Epoch 90/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0638e-06
# Epoch 91/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3742e-06
# Epoch 92/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0731e-06
# Epoch 93/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1666e-06
# Epoch 94/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6657e-06
# Epoch 95/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2880e-06
# Epoch 96/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9288e-06
# Epoch 97/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9122e-06
# Epoch 98/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7619e-06
# Epoch 99/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1970e-06
# Epoch 100/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9094e-06
# Epoch 101/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4683e-06
# Epoch 102/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2646e-06
# Epoch 103/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9466e-06
# Epoch 104/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8353e-06
# Epoch 105/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6956e-06
# Epoch 106/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7738e-06
# Epoch 107/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8948e-06
# Epoch 108/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3115e-06
# Epoch 109/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8539e-06
# Epoch 110/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7962e-06
# Epoch 111/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5782e-06
# Epoch 112/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0439e-06
# Epoch 113/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6116e-06
# Epoch 114/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1845e-06
# Epoch 115/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6688e-06
# Epoch 116/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9391e-06
# Epoch 117/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.2122e-06
# Epoch 118/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6523e-06
# Epoch 119/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3605e-06
# Epoch 120/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2723e-06
# Epoch 121/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3720e-06
# Epoch 122/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7039e-06
# Epoch 123/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2940e-06
# Epoch 124/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2445e-06
# Epoch 125/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1777e-06
# Epoch 126/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7728e-06
# Epoch 127/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2809e-06
# Epoch 128/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5486e-06
# Epoch 129/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6338e-06
# Epoch 130/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1268e-06
# Epoch 131/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7965e-06
# Epoch 132/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9359e-06
# Epoch 133/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.5101e-06
# Epoch 134/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3718e-06
# Epoch 135/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0886e-06
# Epoch 136/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4896e-06
# Epoch 137/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7567e-06
# Epoch 138/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5238e-06
# Epoch 139/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5483e-06
# Epoch 140/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0846e-06
# Epoch 141/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0948e-06
# Epoch 142/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7145e-06
# Epoch 143/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.7237e-06
# Epoch 144/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.5996e-06
# Epoch 145/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4267e-06
# Epoch 146/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3306e-06
# Epoch 147/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4524e-06
# Epoch 148/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8636e-06
# Epoch 149/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5107e-06
# Epoch 150/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3320e-06
# Epoch 151/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3022e-06
# Epoch 152/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4164e-06
# Epoch 153/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6949e-06
# Epoch 154/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2079e-06
# Epoch 155/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9462e-06
# Epoch 156/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8924e-06
# Epoch 157/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5002e-06
# Epoch 158/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5800e-06
# Epoch 159/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8338e-06
# Epoch 160/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0884e-06
# Epoch 161/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3730e-06
# Epoch 162/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0101e-06
# Epoch 163/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8746e-06
# Epoch 164/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0905e-06
# Epoch 165/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.5629e-06
# Epoch 166/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8442e-06
# Epoch 167/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6923e-06
# Epoch 168/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2925e-06
# Epoch 169/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1155e-06
# Epoch 170/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2362e-06
# Epoch 171/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6264e-06
# Epoch 172/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2896e-06
# Epoch 173/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7965e-06
# Epoch 174/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3812e-06
# Epoch 175/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2798e-06
# Epoch 176/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6175e-06
# Epoch 177/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6937e-06
# Epoch 178/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2842e-06
# Epoch 179/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0078e-06
# Epoch 180/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0181e-06
# Epoch 181/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9138e-06
# Epoch 182/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8967e-06
# Epoch 183/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7175e-06
# Epoch 184/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6863e-06
# Epoch 185/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6353e-06
# Epoch 186/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8506e-06
# Epoch 187/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2257e-06
# Epoch 188/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1169e-06
# Epoch 189/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2476e-06
# Epoch 190/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4964e-06
# Epoch 191/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4633e-06
# Epoch 192/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7786e-06
# Epoch 193/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8318e-06
# Epoch 194/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9525e-06
# Epoch 195/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1948e-06
# Epoch 196/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6298e-06
# Epoch 197/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3116e-06
# Epoch 198/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1723e-06
# Epoch 199/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1939e-06
# Epoch 200/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3874e-06
# Epoch 201/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7844e-06
# Epoch 202/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4866e-06
# Epoch 203/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4012e-06
# Epoch 204/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3723e-06
# Epoch 205/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5879e-06
# Epoch 206/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1932e-06
# Epoch 207/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2568e-06
# Epoch 208/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.5829e-06
# Epoch 209/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1136e-06
# Epoch 210/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0342e-06
# Epoch 211/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2484e-06
# Epoch 212/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5349e-06
# Epoch 213/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5544e-06
# Epoch 214/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2270e-06
# Epoch 215/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9755e-06
# Epoch 216/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9188e-06
# Epoch 217/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1384e-06
# Epoch 218/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6727e-06
# Epoch 219/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2961e-06
# Epoch 220/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9846e-06
# Epoch 221/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2657e-06
# Epoch 222/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2058e-06
# Epoch 223/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2186e-06
# Epoch 224/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4947e-06
# Epoch 225/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9702e-06
# Epoch 226/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8918e-06
# Epoch 227/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9318e-06
# Epoch 228/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1511e-06
# Epoch 229/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0852e-06
# Epoch 230/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9988e-06
# Epoch 231/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7073e-06
# Epoch 232/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6176e-06
# Epoch 233/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5893e-06
# Epoch 234/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9298e-06
# Epoch 235/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5963e-06
# Epoch 236/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9431e-06
# Epoch 237/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2964e-06
# Epoch 238/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9118e-06
# Epoch 239/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.0598e-06
# Epoch 240/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9913e-06
# Epoch 241/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9398e-06
# Epoch 242/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1035e-06
# Epoch 243/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5603e-06
# Epoch 244/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2437e-06
# Epoch 245/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1145e-06
# Epoch 246/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1331e-06
# Epoch 247/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3022e-06
# Epoch 248/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6779e-06
# Epoch 249/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2957e-06
# Epoch 250/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2224e-06
# Epoch 251/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1066e-06
# Epoch 252/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6284e-06
# Epoch 253/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1901e-06
# Epoch 254/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.4846e-06
# Epoch 255/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6953e-06
# Epoch 256/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2657e-06
# Epoch 257/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0828e-06
# Epoch 258/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1323e-06
# Epoch 259/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2283e-06
# Epoch 260/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1720e-06
# Epoch 261/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0457e-06
# Epoch 262/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9296e-06
# Epoch 263/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9882e-06
# Epoch 264/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2795e-06
# Epoch 265/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7513e-06
# Epoch 266/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3927e-06
# Epoch 267/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7819e-06
# Epoch 268/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1755e-06
# Epoch 269/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7913e-06
# Epoch 270/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0298e-06
# Epoch 271/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2187e-06
# Epoch 272/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8643e-06
# Epoch 273/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7322e-06
# Epoch 274/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9988e-06
# Epoch 275/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2838e-06
# Epoch 276/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4810e-06
# Epoch 277/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1305e-06
# Epoch 278/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8389e-06
# Epoch 279/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5016e-06
# Epoch 280/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4780e-06
# Epoch 281/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6507e-06
# Epoch 282/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3398e-06
# Epoch 283/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5179e-06
# Epoch 284/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1895e-06
# Epoch 285/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.8240e-06
# Epoch 286/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2857e-06
# Epoch 287/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0518e-06
# Epoch 288/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9204e-06
# Epoch 289/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0633e-06
# Epoch 290/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5071e-06
# Epoch 291/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2074e-06
# Epoch 292/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0835e-06
# Epoch 293/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1036e-06
# Epoch 294/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2761e-06
# Epoch 295/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6281e-06
# Epoch 296/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2481e-06
# Epoch 297/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0849e-06
# Epoch 298/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0294e-06
# Epoch 299/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.4091e-06
# Epoch 300/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2070e-06
# Epoch 301/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4152e-06
# Epoch 302/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7741e-06
# Epoch 303/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2959e-06
# Epoch 304/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1072e-06
# Epoch 305/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0658e-06
# Epoch 306/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0498e-06
# Epoch 307/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0051e-06
# Epoch 308/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9154e-06
# Epoch 309/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9102e-06
# Epoch 310/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0478e-06
# Epoch 311/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3630e-06
# Epoch 312/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8911e-06
# Epoch 313/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3640e-06
# Epoch 314/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8509e-06
# Epoch 315/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9129e-06
# Epoch 316/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5007e-06
# Epoch 317/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6008e-06
# Epoch 318/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0273e-06
# Epoch 319/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6407e-06
# Epoch 320/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6138e-06
# Epoch 321/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8223e-06
# Epoch 322/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4246e-06
# Epoch 323/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6951e-06
# Epoch 324/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5788e-06
# Epoch 325/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9538e-06
# Epoch 326/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6049e-06
# Epoch 327/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3744e-06
# Epoch 328/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5308e-06
# Epoch 329/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0214e-06
# Epoch 330/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1970e-06
# Epoch 331/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7273e-06
# Epoch 332/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8425e-06
# Epoch 333/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.3329e-06
# Epoch 334/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1870e-06
# Epoch 335/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9604e-06
# Epoch 336/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0510e-06
# Epoch 337/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4911e-06
# Epoch 338/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1870e-06
# Epoch 339/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0647e-06
# Epoch 340/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0869e-06
# Epoch 341/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2476e-06
# Epoch 342/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5981e-06
# Epoch 343/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1637e-06
# Epoch 344/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9999e-06
# Epoch 345/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8077e-06
# Epoch 346/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3211e-06
# Epoch 347/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0319e-06
# Epoch 348/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.4662e-06
# Epoch 349/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7837e-06
# Epoch 350/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3633e-06
# Epoch 351/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1087e-06
# Epoch 352/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9909e-06
# Epoch 353/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9245e-06
# Epoch 354/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8589e-06
# Epoch 355/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8425e-06
# Epoch 356/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9049e-06
# Epoch 357/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1016e-06
# Epoch 358/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4846e-06
# Epoch 359/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9412e-06
# Epoch 360/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4850e-06
# Epoch 361/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7465e-06
# Epoch 362/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.7124e-06
# Epoch 363/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9731e-06
# Epoch 364/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3192e-06
# Epoch 365/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7724e-06
# Epoch 366/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5287e-06
# Epoch 367/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4017e-06
# Epoch 368/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5307e-06
# Epoch 369/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9221e-06
# Epoch 370/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8717e-06
# Epoch 371/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3128e-06
# Epoch 372/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9931e-06
# Epoch 373/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0578e-06
# Epoch 374/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5815e-06
# Epoch 375/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3294e-06
# Epoch 376/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5197e-06
# Epoch 377/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1049e-06
# Epoch 378/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3990e-06
# Epoch 379/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9120e-06
# Epoch 380/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.6844e-06
# Epoch 381/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9500e-06
# Epoch 382/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6848e-06
# Epoch 383/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5238e-06
# Epoch 384/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7574e-06
# Epoch 385/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3215e-06
# Epoch 386/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1154e-06
# Epoch 387/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0634e-06
# Epoch 388/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1552e-06
# Epoch 389/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3888e-06
# Epoch 390/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8301e-06
# Epoch 391/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4639e-06
# Epoch 392/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2804e-06
# Epoch 393/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8673e-06
# Epoch 394/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0698e-06
# Epoch 395/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6537e-06
# Epoch 396/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1441e-06
# Epoch 397/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6187e-06
# Epoch 398/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2703e-06
# Epoch 399/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0223e-06
# Epoch 400/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8582e-06
# Epoch 401/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7661e-06
# Epoch 402/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7479e-06
# Epoch 403/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8301e-06
# Epoch 404/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0504e-06
# Epoch 405/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3919e-06
# Epoch 406/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8951e-06
# Epoch 407/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3229e-06
# Epoch 408/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6322e-06
# Epoch 409/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3301e-06
# Epoch 410/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8243e-06
# Epoch 411/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2054e-06
# Epoch 412/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8448e-06
# Epoch 413/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6159e-06
# Epoch 414/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6587e-06
# Epoch 415/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0311e-06
# Epoch 416/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8937e-06
# Epoch 417/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4707e-06
# Epoch 418/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9799e-06
# Epoch 419/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3545e-06
# Epoch 420/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0098e-06
# Epoch 421/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0236e-06
# Epoch 422/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3383e-06
# Epoch 423/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6724e-06
# Epoch 424/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0687e-06
# Epoch 425/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2594e-06
# Epoch 426/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3195e-06
# Epoch 427/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6939e-06
# Epoch 428/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1583e-06
# Epoch 429/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7163e-06
# Epoch 430/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5724e-06
# Epoch 431/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5295e-06
# Epoch 432/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7267e-06
# Epoch 433/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9517e-06
# Epoch 434/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2699e-06
# Epoch 435/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2330e-06
# Epoch 436/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1531e-06
# Epoch 437/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8362e-06
# Epoch 438/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7347e-06
# Epoch 439/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7046e-06
# Epoch 440/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0867e-06
# Epoch 441/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8523e-06
# Epoch 442/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3024e-06
# Epoch 443/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.4212e-06
# Epoch 444/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.4305e-06
# Epoch 445/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3412e-06
# Epoch 446/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9798e-06
# Epoch 447/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9629e-06
# Epoch 448/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3604e-06
# Epoch 449/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0572e-06
# Epoch 450/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.4562e-07
# Epoch 451/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6784e-07
# Epoch 452/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1360e-06
# Epoch 453/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4638e-06
# Epoch 454/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0360e-06
# Epoch 455/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7893e-06
# Epoch 456/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6306e-06
# Epoch 457/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0048e-06
# Epoch 458/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9139e-06
# Epoch 459/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3473e-06
# Epoch 460/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8320e-06
# Epoch 461/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3874e-06
# Epoch 462/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0707e-06
# Epoch 463/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8382e-06
# Epoch 464/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6772e-06
# Epoch 465/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6123e-06
# Epoch 466/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6557e-06
# Epoch 467/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8258e-06
# Epoch 468/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1660e-06
# Epoch 469/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6029e-06
# Epoch 470/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1420e-06
# Epoch 471/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4277e-06
# Epoch 472/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4478e-06
# Epoch 473/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9210e-06
# Epoch 474/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4003e-06
# Epoch 475/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9445e-06
# Epoch 476/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7885e-06
# Epoch 477/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9047e-06
# Epoch 478/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3699e-06
# Epoch 479/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8104e-06
# Epoch 480/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6598e-06
# Epoch 481/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2629e-06
# Epoch 482/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9465e-06
# Epoch 483/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9111e-06
# Epoch 484/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1544e-06
# Epoch 485/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4881e-06
# Epoch 486/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8615e-06
# Epoch 487/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9332e-06
# Epoch 488/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1291e-06
# Epoch 489/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9959e-06
# Epoch 490/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5318e-06
# Epoch 491/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9236e-06
# Epoch 492/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5921e-06
# Epoch 493/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3884e-06
# Epoch 494/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4046e-06
# Epoch 495/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5278e-06
# Epoch 496/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9473e-06
# Epoch 497/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4931e-06
# Epoch 498/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9785e-06
# Epoch 499/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6046e-06
# Epoch 500/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1502e-06
# Epoch 501/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5769e-06
# Epoch 502/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3639e-06
# Epoch 503/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3450e-06
# Epoch 504/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7866e-06
# Epoch 505/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7925e-06
# Epoch 506/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5925e-06
# Epoch 507/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.8013e-06
# Epoch 508/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4458e-06
# Epoch 509/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9625e-06
# Epoch 510/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5537e-06
# Epoch 511/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6557e-06
# Epoch 512/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1747e-06
# Epoch 513/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.4489e-07
# Epoch 514/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 8.8088e-07
# Epoch 515/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9.3620e-07
# Epoch 516/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1358e-06
# Epoch 517/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4987e-06
# Epoch 518/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1093e-06
# Epoch 519/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8806e-06
# Epoch 520/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6802e-06
# Epoch 521/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9682e-06
# Epoch 522/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8044e-06
# Epoch 523/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2329e-06
# Epoch 524/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6965e-06
# Epoch 525/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2272e-06
# Epoch 526/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8878e-06
# Epoch 527/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6621e-06
# Epoch 528/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5456e-06
# Epoch 529/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5387e-06
# Epoch 530/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6571e-06
# Epoch 531/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8966e-06
# Epoch 532/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2979e-06
# Epoch 533/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7415e-06
# Epoch 534/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1978e-06
# Epoch 535/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2846e-06
# Epoch 536/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1046e-06
# Epoch 537/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6120e-06
# Epoch 538/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2517e-06
# Epoch 539/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0348e-06
# Epoch 540/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0946e-06
# Epoch 541/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2963e-06
# Epoch 542/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3675e-06
# Epoch 543/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2207e-06
# Epoch 544/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9557e-06
# Epoch 545/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8280e-06
# Epoch 546/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8998e-06
# Epoch 547/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1435e-06
# Epoch 548/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5370e-06
# Epoch 549/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7464e-06
# Epoch 550/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9026e-06
# Epoch 551/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9143e-06
# Epoch 552/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9335e-06
# Epoch 553/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3850e-06
# Epoch 554/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8780e-06
# Epoch 555/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4937e-06
# Epoch 556/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3506e-06
# Epoch 557/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3269e-06
# Epoch 558/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5213e-06
# Epoch 559/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0474e-06
# Epoch 560/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.4080e-06
# Epoch 561/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5224e-06
# Epoch 562/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6457e-06
# Epoch 563/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5858e-06
# ...
# Epoch 813/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6542e-06
# Epoch 814/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0610e-06
# Epoch 815/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9883e-06
# Epoch 816/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.8258e-06
# Epoch 817/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 3.3364e-06
# Epoch 818/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.3183e-06
# Epoch 819/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7421e-06
# Epoch 820/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5503e-06
# Epoch 821/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6040e-06
# Epoch 822/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8355e-06
# Epoch 823/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0260e-06
# Epoch 824/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.1647e-06
# Epoch 825/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0658e-06
# Epoch 826/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9629e-06
# Epoch 827/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7641e-06
# Epoch 828/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6685e-06
# Epoch 829/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5469e-06
# Epoch 830/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5383e-06
# Epoch 831/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5816e-06
# Epoch 832/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9089e-06
# Epoch 833/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7226e-06
# Epoch 834/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6372e-06
# Epoch 835/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3807e-06
# Epoch 836/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4341e-06
# Epoch 837/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8689e-06
# Epoch 838/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6572e-06
# Epoch 839/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6631e-06
# Epoch 840/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8014e-06
# Epoch 841/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9138e-06
# Epoch 842/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0471e-06
# Epoch 843/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0275e-06
# Epoch 844/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0100e-06
# Epoch 845/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8105e-06
# Epoch 846/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6612e-06
# Epoch 847/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4806e-06
# Epoch 848/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4543e-06
# Epoch 849/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5380e-06
# Epoch 850/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9435e-06
# Epoch 851/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8405e-06
# Epoch 852/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6787e-06
# Epoch 853/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3379e-06
# Epoch 854/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3718e-06
# Epoch 855/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7797e-06
# Epoch 856/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5246e-06
# Epoch 857/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5151e-06
# Epoch 858/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7094e-06
# Epoch 859/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9572e-06
# Epoch 860/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2192e-06
# Epoch 861/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1558e-06
# Epoch 862/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9883e-06
# Epoch 863/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6802e-06
# Epoch 864/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5364e-06
# Epoch 865/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4717e-06
# Epoch 866/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5983e-06
# Epoch 867/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8642e-06
# Epoch 868/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4398e-06
# Epoch 869/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2298e-06
# Epoch 870/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2097e-06
# Epoch 871/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5069e-06
# Epoch 872/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8125e-06
# Epoch 873/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5118e-06
# Epoch 874/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5288e-06
# Epoch 875/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7793e-06
# Epoch 876/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1718e-06
# Epoch 877/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2976e-06
# Epoch 878/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2194e-06
# Epoch 879/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8796e-06
# Epoch 880/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6736e-06
# Epoch 881/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5404e-06
# Epoch 882/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6075e-06
# Epoch 883/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7115e-06
# Epoch 884/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9102e-06
# Epoch 885/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.3489e-06
# Epoch 886/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9162e-06
# Epoch 887/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9070e-06
# Epoch 888/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2477e-06
# Epoch 889/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7441e-06
# Epoch 890/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5429e-06
# Epoch 891/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6706e-06
# Epoch 892/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0558e-06
# Epoch 893/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3255e-06
# Epoch 894/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3696e-06
# Epoch 895/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0448e-06
# Epoch 896/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7822e-06
# Epoch 897/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5569e-06
# Epoch 898/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5723e-06
# Epoch 899/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6606e-06
# Epoch 900/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7730e-06
# Epoch 901/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9618e-06
# Epoch 902/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4325e-06
# Epoch 903/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8811e-06
# Epoch 904/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5929e-06
# Epoch 905/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0403e-06
# Epoch 906/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6236e-06
# Epoch 907/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5559e-06
# Epoch 908/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8247e-06
# Epoch 909/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2274e-06
# Epoch 910/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4900e-06
# Epoch 911/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2725e-06
# Epoch 912/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9791e-06
# Epoch 913/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6243e-06
# Epoch 914/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5088e-06
# Epoch 915/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5352e-06
# Epoch 916/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6722e-06
# Epoch 917/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7795e-06
# Epoch 918/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0510e-06
# Epoch 919/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5949e-06
# Epoch 920/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8281e-06
# Epoch 921/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4462e-06
# Epoch 922/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8471e-06
# Epoch 923/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5449e-06
# Epoch 924/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5650e-06
# Epoch 925/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8944e-06
# Epoch 926/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3818e-06
# Epoch 927/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4800e-06
# Epoch 928/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2943e-06
# Epoch 929/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8467e-06
# Epoch 930/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5803e-06
# Epoch 931/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4374e-06
# Epoch 932/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5195e-06
# Epoch 933/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6278e-06
# Epoch 934/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7692e-06
# Epoch 935/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.1030e-06
# Epoch 936/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6737e-06
# Epoch 937/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8679e-06
# Epoch 938/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3193e-06
# Epoch 939/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7891e-06
# Epoch 940/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5128e-06
# Epoch 941/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5780e-06
# Epoch 942/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9712e-06
# Epoch 943/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3811e-06
# Epoch 944/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5194e-06
# Epoch 945/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1622e-06
# Epoch 946/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8205e-06
# Epoch 947/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5009e-06
# Epoch 948/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4357e-06
# Epoch 949/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4924e-06
# Epoch 950/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6098e-06
# Epoch 951/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7251e-06
# Epoch 952/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0686e-06
# Epoch 953/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7009e-06
# Epoch 954/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8663e-06
# Epoch 955/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3865e-06
# Epoch 956/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7857e-06
# Epoch 957/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5290e-06
# Epoch 958/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6177e-06
# Epoch 959/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9812e-06
# Epoch 960/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.3933e-06
# Epoch 961/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.3614e-06
# Epoch 962/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1241e-06
# Epoch 963/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7123e-06
# Epoch 964/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5029e-06
# Epoch 965/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4264e-06
# Epoch 966/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5306e-06
# Epoch 967/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5940e-06
# Epoch 968/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6695e-06
# Epoch 969/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9400e-06
# Epoch 970/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5711e-06
# Epoch 971/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9798e-06
# Epoch 972/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4968e-06
# Epoch 973/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9114e-06
# Epoch 974/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5933e-06
# Epoch 975/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6547e-06
# Epoch 976/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9931e-06
# Epoch 977/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2337e-06
# Epoch 978/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2672e-06
# Epoch 979/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9549e-06
# Epoch 980/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6931e-06
# Epoch 981/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4638e-06
# Epoch 982/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4794e-06
# Epoch 983/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5802e-06
# Epoch 984/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6479e-06
# Epoch 985/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6362e-06
# Epoch 986/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8005e-06
# Epoch 987/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3532e-06
# Epoch 988/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9407e-06
# Epoch 989/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7521e-06
# Epoch 990/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0725e-06
# Epoch 991/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6965e-06
# Epoch 992/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6878e-06
# Epoch 993/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8912e-06
# Epoch 994/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1121e-06
# Epoch 995/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0656e-06
# Epoch 996/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9214e-06
# Epoch 997/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6270e-06
# Epoch 998/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4858e-06
# Epoch 999/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4663e-06
# Epoch 1000/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6506e-06

# %% [markdown]
# ## Evaluate LSTM Model

# %%
#  Combine training and testing datasets
combined_set = np.concatenate((train_data, test_data), axis=1)

# %%
#  Evaluate model at each week for the test set
evaluated_weeks = []
for i in range(0, test_data.shape[1]):
    input_series = combined_set[0:, i:i + 77]

    X_test = input_series[0:, :-1].reshape(1, input_series.shape[1] - 1, 7)
    Y_test = input_series[0:, -1:][0]

    result = model.evaluate(x=X_test, y=Y_test, verbose=0)
    evaluated_weeks.append(result)

# %%
#  Plot MSE for all evaluated weeks
ax = pd.Series(evaluated_weeks).plot(drawstyle="steps-post",
                                     figsize=(14, 4),
                                     color='#2c3e50',
                                     grid=True,
                                     title='Mean Squared Error (MSE) for Test Data')

ax.set_xticks(range(0, len(evaluated_weeks)))
ax.set_xlabel("Predicted Week")
ax.set_ylabel("MSE")
plt.show()

# %% [markdown]
# ## Interpreting Model Results

# %% [markdown]
# ### Make Predictions

# %%
#  Make predictions for each of the 19 weeks
#  in the test set
predicted_weeks = []
for i in range(0, test_data.shape[1]):
    input_series = combined_set[0:, i:i + 76]
    predicted_weeks.append(model.predict(input_series))

# %%
#  Flatten `predicted_weeks` to get a list
#  of predictions for each day in the 19 weeks
predicted_days = []
for week in predicted_weeks:
    predicted_days += list(week[0])

# %%
#  Create list of dates associated with predictions
last_day = datetime.strptime(train['date'].max(), '%Y-%m-%d')
list_of_days = []
for days in range(1, len(predicted_days) + 1):
    D = (last_day + timedelta(days=days)).strftime('%Y-%m-%d')
    list_of_days.append(D)

# %%
#  Create dataframe with predicted values
predicted = pd.DataFrame({
    'date': list_of_days,
    'close_point_relative_normalization': predicted_days
})
predicted.head()
# Out:
#          date  close_point_relative_normalization
# 0  2017-06-25                           -0.000092
# 1  2017-06-26                            0.015169
# 2  2017-06-27                            0.069046
# 3  2017-06-28                            0.053480
# 4  2017-06-29                            0.061346

# %%
#  Convert `date` variable to datetime
predicted['date'] = predicted['date'].apply(
    lambda x: datetime.strptime(x, '%Y-%m-%d'))

test['date'] = test['date'].apply(
    lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
def plot_two_series(A, B, variable, title):
    """Plot two series using the same `date` index. 
    
    Parameters
    ----------
    A, B: pd.DataFrame
        Dataframe with a `date` key and a variable
        passed in the `variable` parameter. Parameter A
        represents the "Observed" series and B the "Predicted"
        series. These will be labelled respectively. 
    
    variable: str
        Variable to use in plot.
    
    title: str
        Plot title.
    """
    plt.figure(figsize=(14, 4))
    plt.xlabel('Observed and predicted')

    ax1 = A.set_index('date')[variable].plot(
        color='#d35400', grid=True, label='Observed', title=title)

    ax2 = B.set_index('date')[variable].plot(
        color='grey', grid=True, label='Predicted')
    
    ax1.set_xlabel("Predicted Week")
    ax1.set_ylabel("Predicted Values")

    plt.legend()
    plt.show()

# %%
#  Plot predicted normalized prices
#  against actual normalized prices
plot_two_series(A=test[:-3],
                B=predicted,
                variable='close_point_relative_normalization',
                title='Normalized Predictions per Week')

# %% [markdown]
# ### De-normalize Predictions

# %%
#  Add variable `iso_week` by stripping the Year and Week from `date`
predicted['iso_week'] = predicted['date'].apply(
    lambda x: x.strftime('%Y-%U'))

# %%
def denormalize(reference, series,
                normalized_variable='close_point_relative_normalization',
                denormalized_variable='close'):
    """Denormalize the values for a given series.

    Parameters
    ----------
    reference: pd.DataFrame
        DataFrame to use as reference. This dataframe
        contains both a week index and the USD price
        reference that we are interested on.

    series: pd.DataFrame
        DataFrame with the predicted series. The
        DataFrame must have the same columns as the
        `reference` dataset.

    normalized_variable: str, default 'close_point_relative_normalization'
        Variable to use in normalization.

    denormalized_variable: str, default `close`
        Variable to use in de-normalization.

    Returns
    -------
    A modified DataFrame with the new variable provided
    in `denormalized_variable` parameter.
    """
    week_values = reference[reference['iso_week'] == series['iso_week'].values[0]]
    last_value = week_values[denormalized_variable].values[0]
    series[denormalized_variable] = last_value * (series[normalized_variable] + 1)

    return series

# %%
#  Denormalize predictions
predicted_close = predicted.groupby('iso_week').apply(
    lambda x: denormalize(test[:-3], x))

# %%
#  Plot denormalized predictions and observed closing prices in test set
plot_two_series(A=test[:-3],
                B=predicted_close,
                variable='close',
                title='De-normalized Predictions per Week')

# %% [markdown]
# ### Calculate RMSE and MAPE

# %%
A = test[:-3]['close_point_relative_normalization']
B = predicted_close['close_point_relative_normalization']

print(f'Normalized RMSE: {rmse(A, B):.2f}')
# Out:
# Normalized RMSE: 0.10

# %%
A = test[:-3]['close']
B = predicted_close['close']

print(f'De-normalized RMSE: {rmse(A, B):.2f}')
print(f'De-normalized MAPE: {mape(A, B):.2f}')
# Out:
# De-normalized RMSE: 356.64
# De-normalized MAPE: 6.60
