# %% [markdown]
# # Activity 5: Assembling a Deep Learning System
# In this activity, we will train the first version of our LSTM model using Bitcoin daily closing prices. These prices will be organized using the weeks of both 2016 and 2017. We do that because we are interested in predicting the prices of a week's worth of trading.

# %%
# %autosave 5

#  Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-white')

from keras.models import load_model
# Out:
# Autosaving every 5 seconds

# %%
#  Import training dataset
train = pd.read_csv('train_dataset.csv')
train.head()
# Out:
#          date  ... volume_point_relative_normalization
# 0  2016-01-01  ...                            0.000000
# 1  2016-01-02  ...                           -0.170410
# 2  2016-01-03  ...                            0.000000
# 3  2016-01-04  ...                           -0.029175
# 4  2016-01-05  ...                           -0.128961
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Reshape Data

# %%
def create_groups(data, group_size=7):
    """Create distinct groups from a continuous series.
    
    Parameters
    ----------
    data: np.array
        Series of continious observations.

    group_size: int, default 7
        Determines how large the groups are. That is,
        how many observations each group contains.
    
    Returns
    -------
    A Numpy array object. 
    """
    samples = []
    for i in range(0, len(data), group_size):
        sample = list(data[i:i + group_size])
        if len(sample) == group_size:
            samples.append(np.array(sample).reshape(1, group_size))
    
    return np.array(samples)

# %%
#  Find the remainder when the number of observations is divided by group size
len(train) % 7
# Out:
# 2

# %%
#  Create groups of 7 from our data.
#  We drop the first two observations so that the
#  number of total observations is divisible by the `group_size`.
data = create_groups(train['close_point_relative_normalization'][2:].values)
print(data.shape)
# Out:
# (77, 1, 7)

# %%
#  Reshape data into format expected by LSTM layer
X_train = data[:-1, :].reshape(1, 76, 7)
Y_validation = data[-1].reshape(1, 7)
print(X_train.shape)
print(Y_validation.shape)
# Out:
# (1, 76, 7)
# (1, 7)

# %% [markdown]
# ## Load Our Model

# %%
#  Load our previously trained model 
model = load_model('bitcoin_lstm_v0.h5')

# %% [markdown]
# ## Train model

# %%
# %%time
#  Train the model
history = model.fit(
    x=X_train, y=Y_validation,
    batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 8/100
# 1/1 [==============================] - 0s 989us/step - loss: 0.0011
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.8085e-04
# Epoch 10/100
# 1/1 [==============================] - 0s 971us/step - loss: 8.7883e-04
# Epoch 11/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.8717e-04
# Epoch 12/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0435e-04
# Epoch 13/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2922e-04
# Epoch 14/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6089e-04
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9866e-04
# Epoch 16/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4198e-04
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9036e-04
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4344e-04
# Epoch 19/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0086e-04
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6233e-04
# Epoch 21/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2757e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9635e-04
# Epoch 23/100
# 1/1 [==============================] - 0s 985us/step - loss: 1.6842e-04
# Epoch 24/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4355e-04
# Epoch 25/100
# 1/1 [==============================] - 0s 946us/step - loss: 1.2155e-04
# Epoch 26/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0219e-04
# Epoch 27/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.5267e-05
# Epoch 28/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0586e-05
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.7944e-05
# Epoch 30/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7148e-05
# Epoch 31/100
# 1/1 [==============================] - 0s 916us/step - loss: 3.8008e-05
# Epoch 32/100
# 1/1 [==============================] - 0s 902us/step - loss: 3.0341e-05
# Epoch 33/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3971e-05
# Epoch 34/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8734e-05
# Epoch 35/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4473e-05
# Epoch 36/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1047e-05
# Epoch 37/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.3238e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 975us/step - loss: 6.1872e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5330e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 998us/step - loss: 3.2704e-06
# Epoch 41/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3211e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6188e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1080e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.4328e-07
# Epoch 45/100
# 1/1 [==============================] - 0s 968us/step - loss: 4.8793e-07
# Epoch 46/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1292e-07
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9570e-07
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1914e-07
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0794e-08
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5055e-08
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.0039e-08
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6667e-07
# Epoch 53/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2562e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9554e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8102e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3224e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1271e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4877e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8987e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5555e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4882e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6992e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9250e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0093e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9141e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8873e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 999us/step - loss: 1.9284e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1612e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5089e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9206e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1460e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 987us/step - loss: 3.0960e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8247e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5685e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3964e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4238e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 995us/step - loss: 2.5098e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 992us/step - loss: 2.6993e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7338e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7900e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6529e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6034e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4341e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4006e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3479e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 943us/step - loss: 2.5516e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0523e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.8316e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8965e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0638e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3742e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0731e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1666e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6657e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2880e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9288e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 989us/step - loss: 3.9122e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7619e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1970e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9094e-06
# CPU times: user 3.15 s, sys: 165 ms, total: 3.32 s
# Wall time: 3.41 s

# %%
#  Plot loss function
pd.Series(history.history['loss']).plot(figsize=(14, 4));

# %% [markdown]
# ## Make Predictions

# %%
#  Make predictions using X_train data
predictions = model.predict(x=X_train)[0]
predictions
# Out:
# array([-0.00113241,  0.01640296,  0.06942877,  0.05388029,  0.06352028,
#         0.0792512 ,  0.02581236], dtype=float32)

# %%
def denormalize(series, last_value):
    """Denormalize the values for a given series.
    
    This uses the last value available (i.e. the last
    closing price of the week before our prediction)
    as a reference for scaling the predicted results.
    """
    result = last_value * (series + 1)
    return result

# %%
#  Denormalize predictions
last_weeks_value = train[train['date'] == train['date'][:-7].max()]['close'].values[0]

denormalized_prediction = denormalize(predictions, last_weeks_value)
denormalized_prediction
# Out:
# array([2652.8723, 2699.444 , 2840.2744, 2798.9795, 2824.5823, 2866.3616,
#        2724.4346], dtype=float32)

# %%
#  Plot denormalized predictions against actual predictions
plt.figure(figsize=(14, 4))

plt.plot(train['close'][-7:].values, label='Actual')
plt.plot(denormalized_prediction, color='#d35400', label='Predicted')

plt.grid()
plt.legend();

# %%
prediction_plot = np.zeros(len(train)-2)
prediction_plot[:] = np.nan
prediction_plot[-7:] = denormalized_prediction

plt.figure(figsize=(14, 4))
plt.plot(train['close'][-30:].values, label='Actual')
plt.plot(prediction_plot[-30:], color='#d35400', linestyle='--', label='Predicted')
plt.axvline(30 - 7, color='r', linestyle='--', linewidth=1)

plt.grid()
plt.legend(loc='lower right');

# %%
train.to_csv('train_dataset1.csv',index = False)
model.save('bitcoin_lstm_v0_trained.h5')

# %% [markdown]
# In this activity, we have assembled a complete deep learning system: from data to prediction. The model created in this activity need a number of improvements before it can be considered useful. However, it serves as a great starting point from which we will continuously improve.
